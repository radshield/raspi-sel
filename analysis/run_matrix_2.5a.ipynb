# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../results/run_matrix_2.5a.csv')
df
# Out:
#                           time  cpu_percent  virtual_memory  adc_voltage
# 0   2023-04-07 16:36:38.676228         24.2            25.9     0.006125
# 1   2023-04-07 16:36:38.787486          2.3            25.8     0.003625
# 2   2023-04-07 16:36:38.893963          0.0            25.8     0.004000
# 3   2023-04-07 16:36:39.000368          0.0            25.8     0.003750
# 4   2023-04-07 16:36:39.106867          2.3            25.8     0.004125
# ..                         ...          ...             ...          ...
# 95  2023-04-07 16:36:48.876977        100.0            26.7     0.010125
# 96  2023-04-07 16:36:48.984237        100.0            26.7     0.007250
# 97  2023-04-07 16:36:49.091331        100.0            27.3     0.007625
# 98  2023-04-07 16:36:49.198760        100.0            27.4     0.008000
# 99  2023-04-07 16:36:49.306251         95.3            27.3     0.003125
#
# [100 rows x 4 columns]

# %%
df.plot(x='time', y='adc_voltage')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)

# %%
df.plot(x='time', y='cpu_percent')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)

# %%
df.plot(x='time', y='virtual_memory')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
